# %%
#import the requried libraries
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import math

# %%
#import the csv file of endorsements
df_raw = pd.read_csv('endorsements-2020.csv')

#drop rows that contain null values for endorsees
df = df_raw[df_raw['endorsee'].notnull()]

#drop the source column to clean up the look of the dataframe
df.drop(columns=['source'],inplace=True)

#show the resulting dataframe
df
# Out:
#            date            position         city state          endorser  \
# 0    2017-07-28      representative          NaN    MD       David Trone
# 1    2019-01-02            governor          NaN    NY      Andrew Cuomo
# 2    2019-01-03             senator          NaN    CA  Dianne Feinstein
# 3    2019-01-08             senator          NaN    DE  Thomas R. Carper
# 4    2019-01-12               mayor  San Antonio    TX     Ron Nirenberg
# ..          ...                 ...          ...   ...               ...
# 244  2020-02-02      representative          NaN    IL    Danny K. Davis
# 245  2020-02-03     state treasurer          NaN    CA          Fiona Ma
# 246  2020-02-04   state comptroller          NaN    CT       Kevin Lembo
# 247  2020-02-04  secretary of state          NaN    CA      Alex Padilla
# 248  2020-02-04     minority leader          NaN    AR     Fredrick Love
#
#               endorsee endorser party  order                   category  \
# ...

# %%
df.sort_values(['endorsee'],ascending=True,inplace=True)
#create a list of unique endorsees
z = list(df['endorsee'].unique())
print(z)
# Out:
# ['Amy Klobuchar', 'Bernie Sanders', "Beto O'Rourke", 'Cory Booker', 'Elizabeth Warren', 'Jay Inslee', 'Joe Biden', 'John Delaney', 'Julian Castro', 'Kamala Harris', 'Kirsten Gillibrand', 'Michael Bennet', 'Michael Bloomberg', 'Pete Buttigieg', 'Steve Bullock', 'Tom Steyer']
# /home/patrick/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#find and print the total number of available endorsement points
print("Total number of available points:",df_raw['points'].sum(axis=0))

#find and print the number of endorsement points each candidate has recieved
for x in range(len(z)):
    df_i = df.loc[df['endorsee'] == (z[x])]
    print("Point total of",z[x],":",df_i['points'].sum(axis = 0))
# Out:
# Total number of available points: 2414
# Point total of Amy Klobuchar : 53
# Point total of Bernie Sanders : 55
# Point total of Beto O'Rourke : 3
# Point total of Cory Booker : 54
# Point total of Elizabeth Warren : 87
# Point total of Jay Inslee : 11
# Point total of Joe Biden : 252
# Point total of John Delaney : 6
# Point total of Julian Castro : 4
# Point total of Kamala Harris : 66
# Point total of Kirsten Gillibrand : 3
# Point total of Michael Bennet : 15
# Point total of Michael Bloomberg : 50
# Point total of Pete Buttigieg : 36
# Point total of Steve Bullock : 7
# Point total of Tom Steyer : 1

# %%
df.sort_values(['points'],ascending=False,inplace=True)
df
# Out:
# /home/patrick/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            date             position city state           endorser  \
# 14   2019-02-06  past vice president  NaN    MN     Walter Mondale
# 240  2020-01-30                mayor  NaN    DC      Muriel Bowser
# 12   2019-02-01             governor  NaN    NJ        Phil Murphy
# 105  2019-07-02             governor  NaN    CT         Ned Lamont
# 1    2019-01-02             governor  NaN    NY       Andrew Cuomo
# ..          ...                  ...  ...   ...                ...
# 76   2019-04-25           DNC member  NaN    DC  Cristobal J. Alex
# 113  2019-07-23           DNC member  NaN    VT   Mary M. Sullivan
# ...
